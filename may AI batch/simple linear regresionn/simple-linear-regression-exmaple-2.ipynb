# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Salary_dataset.csv")

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
plt.scatter(data["YearsExperience"], data["Salary"], color = "red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.model_selection import train_test_split

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
# x = data["YearsExperience"]
# y = data["Salary"]

x = data.iloc[ :, 1:2]

y = data.iloc[:, -1]
# (1, -1)

# %%
data.head(2)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.9)

# %%
# zx = np.array([[34, 45, 67, 78, 34], [45, 56, 34, 45, 45]])

# %%
# zx.ndim

# %%
# zx.reshape(-1)

# %%
x_train.shape
# Out:
# (27, 1)

# %%
x_test.shape
# Out:
# (3, 1)

# %%
data.shape
# Out:
# (30, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# fit() -> traning the model

# model.fit(data["YearsExperience"].values, data["Salary"].values)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# y = mx + b

# sallery = slop * exprerience + intercept

# %%
model.coef_
# Out:
# array([9327.41533764])

# %%
model.intercept_
# Out:
# 26002.896106470427

# %%
y = (9327.41533764 * 9) + 26002.896106470427

y
# Out:
# 109949.63414523043

# %%
zx = np.array(8)

pq = zx.reshape(1, -1)

model.predict(pq)
# Out:
# C:\Users\17nru\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([100622.2188076])

# %%
plt.scatter(x_train, y_train, color = "blue", label = "Traing Data")
plt.scatter(x_test, y_test, color = "red", label = "testing data")
plt.plot(x_train, model.predict(x_train), color = "green", label = "Predicted Line")
plt.legend()

# %%
# joblib  ===> to saveing the model

# %%
# !pip install joblib
# Out:
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import joblib

# %%
joblib.dump(model, "predicted_sallery_by_expreience.joblib")
# Out:
# ['predicted_sallery_by_expreience.joblib']
