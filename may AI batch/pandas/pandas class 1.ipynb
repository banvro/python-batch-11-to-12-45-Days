# %%
# import numpy

# %%
Pandas : 
    Python Data Analytics

Numpy : 2005
Pandas : 2008

Pandas:
    JSON
    Excel Sheets
    CSV..

# %%
Pandas Help Us to Persform Some Operation On Datasets:
    1) Data Exploring
    2) Data Manupiulcation
    3) Data Claning
    4) Data Analyzing..

# %%
Data Structurs:
    1) Sereis  : its a single column in a table
    2) DataFrame : combination of multilpe series

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
sr = pd.Series([12, 3, 45, 56, 67, 45])  #index

# %%
sr
# Out:
# 0    12
# 1     3
# 2    45
# 3    56
# 4    67
# 5    45
# dtype: int64

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
# DataFrame:

# %%
data = pd.DataFrame({
    "Name" : ["hlo", "abc", "ok", "done"],
    "Age" : [23, 45, 23, 4], 
    "Phone Number" : [678768768786, 678678678678, 567456456, 456456456]
})

# %%
data
# Out:
#    Name  Age  Phone Number
# 0   hlo   23  678768768786
# 1   abc   45  678678678678
# 2    ok   23     567456456
# 3  done    4     456456456

# %%
# Loading Files and datasets

# %%
data = pd.read_csv("StressLevelDataset.csv")

# %%
data
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Explring or Analysis

# %%
data
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
# to_string()

# %%
data.to_string()
# Out:
# '      anxiety_level  self_esteem  mental_health_history  depression  headache  blood_pressure  sleep_quality  breathing_problem  noise_level  living_conditions  safety  basic_needs  academic_performance  study_load  teacher_student_relationship  future_career_concerns  social_support  peer_pressure  extracurricular_activities  bullying  stress_level\n0                14           20                      0          11         2               1              2                  4            2                  3       3            2                     3           2                             3                       3               2              3                           3         2             1\n1                15            8                      1          15         5               3              1                  4            3                  1       2            2                     1           4                             1                       5               1       
# ...

# %%
head() -> it returns top 5 rows/ or max

# %%
data.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.head(10)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
# 5             20           13                      1          21         3
# 6              4           26                      0           6         1
# 7             17            3                      1          22         4
# 8             13           22                      1          12         3
# 9              6            8                      0          27         4
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# ...

# %%
tail() -> it returns last 5 rows

# %%
data.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.tail(7)
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1093              1           30                      0           4         1
# 1094              7           17                      0           0         4
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1093               2              5                  2            1
# 1094               3              5                  4            5
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# ...

# %%
sample()  --> return a random rows / number of random rows..

# %%
data.sample()
# Out:
#      anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 214              8           29                      0           5         1
#
#      blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 214               2              5                  1            2
#
#      living_conditions  ...  basic_needs  academic_performance  study_load  \
# 214                  4  ...            4                     5           1
#
#      teacher_student_relationship  future_career_concerns  social_support  \
# 214                             4                       1               3
#
#      peer_pressure  extracurricular_activities  bullying  stress_level
# 214              2                           2         1             0
#
# [1 rows x 21 columns]

# %%
data.sample(5)
# Out:
#      anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 505              2           27                      0           7         1
# 361             12           19                      0          12         3
# 147             18            3                      1          20         3
# 563             19           14                      1          26         5
# 395              5           25                      0           6         1
#
#      blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 505               2              4                  1            2
# 361               1              3                  4            3
# 147               3              1                  5            4
# 563               3              1                  5            5
# 395               2              5                  1            1
#
#      living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
head()
tail()
sample()
to_string()

# %%
# info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
# To get data::::::

# %%
# to get a single column

# %%
data
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
data["self_esteem"]
# Out:
# 0       20
# 1        8
# 2       18
# 3       12
# 4       28
#         ..
# 1095    17
# 1096    12
# 1097    26
# 1098     0
# 1099     6
# Name: self_esteem, Length: 1100, dtype: int64

# %%
# data["self_esteem", "mental_health_history"]

# %%
# loc[]

# iloc[]

# %%
# datasetmame.iloc[rows, columns]

# working on indexnumbers

# %%
data.iloc[ : , [2, 4]]
# Out:
#       mental_health_history  headache
# 0                         0         2
# 1                         1         5
# 2                         1         2
# 3                         1         4
# 4                         0         2
# ...                     ...       ...
# 1095                      0         3
# 1096                      0         0
# 1097                      0         1
# 1098                      1         5
# 1099                      1         3
#
# [1100 rows x 2 columns]

# %%
data.head(3)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# 0                  3  ...            2                     3           2
# 1                  1  ...            2                     1           4
# 2                  2  ...            2                     2           3
#
#    teacher_student_relationship  future_career_concerns  social_support  \
# ...

# %%
data.iloc[:, 3 : 7]
# Out:
#       depression  headache  blood_pressure  sleep_quality
# 0             11         2               1              2
# 1             15         5               3              1
# 2             14         2               1              2
# 3             15         4               3              1
# 4              7         2               3              5
# ...          ...       ...             ...            ...
# 1095          14         3               1              3
# 1096           8         0               3              0
# 1097           3         1               2              5
# 1098          19         5               3              1
# 1099          15         3               3              0
#
# [1100 rows x 4 columns]

# %%
data.iloc[10 : 21, 3 : 7]
# Out:
#     depression  headache  blood_pressure  sleep_quality
# 10          25         4               3              1
# 11          22         3               3              1
# 12           8         1               2              4
# 13          24         4               3              1
# 14           3         1               2              4
# 15          14         3               1              2
# 16           1         1               2              4
# 17           3         1               2              4
# 18          12         3               1              2
# 19          25         4               3              1
# 20           0         1               2              4

# %%
# loc

# %%
data["headache"]
# Out:
# 0       2
# 1       5
# 2       2
# 3       4
# 4       2
#        ..
# 1095    3
# 1096    0
# 1097    1
# 1098    5
# 1099    3
# Name: headache, Length: 1100, dtype: int64
