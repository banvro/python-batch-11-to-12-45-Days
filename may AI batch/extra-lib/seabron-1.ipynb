# %%
numpy
pandas
matplotlib
plotly
seaborn

# %%
# !pip install seaborn
# Out:
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import random

# %%
data = pd.DataFrame({
    "Month" : ["Jan", "Feb", "March", "Aprial", "May", "June"],
    "Profit" : [12, 20, 34, 45, 56, 67]
})

# %%
data
# Out:
#     Month  Profit
# 0     Jan      12
# 1     Feb      20
# 2   March      34
# 3  Aprial      45
# 4     May      56
# 5    June      67

# %%
sns.lineplot(
    data, 
    x = "Month",
    y = "Profit",
)

# plt.annotate(xy = ("jan", 12), text = "hey")

# plt.annotate(xy = (data["Month"][0], data["Profit"][0]), text = "hey")
# Out:
# Text(Jan, 12, 'hey')

# %%
sns.lineplot(
    data, 
    x = "Month",
    y = "Profit",
)
# Out:
# <Axes: xlabel='Month', ylabel='Profit'>

# %%
data
# Out:
#     Month  Profit
# 0     Jan      12
# 1     Feb      20
# 2   March      34
# 3  Aprial      45
# 4     May      56
# 5    June      67

# %%
# data(Profit : 1)

data["Profit"][1]
# Out:
# 20

# %%
sns.lineplot(
    data, 
    x = "Month",
    y = "Profit",
)
# Out:
# <Axes: xlabel='Month', ylabel='Profit'>

# %%
sns.lineplot(
    data, 
    x = "Month",
    y = "Profit",
)

for i in range(len("Month")):
    plt.annotate(xy = (data["Month"][i], data["Profit"][i]), text = f"({data["Month"][i]}, {data["Profit"][i]})")

# %%
sns.lineplot(
    data, 
    x = "Month",
    y = "Profit",
)

for i in range(len("Month")):
    plt.annotate(xy = (data["Month"][i], data["Profit"][i]), text = f"({data["Month"][i]}, {data["Profit"][i]})")
    # plt.text(data["Month"][i], data["Profit"][i], f"({data["Month"][i]}, {data["Profit"][i]})")

# %%
# scatterplot

# %%
data = pd.DataFrame({
    "abc" : random.randint(10, 30, size = 50),
    "xyz" : random.randint(10, 30, size = 50),
    "sizees" : random.randint(300, 1000, size = 50)
})

# %%
data
# Out:
#     abc  xyz  sizees
# 0    26   19     633
# 1    22   19     682
# 2    18   27     694
# 3    24   20     488
# 4    22   19     476
# 5    18   22     989
# 6    11   27     545
# 7    15   21     504
# 8    25   18     928
# 9    15   25     393
# 10   18   23     709
# 11   14   14     883
# 12   18   25     678
# 13   13   25     989
# 14   12   14     692
# 15   23   17     465
# 16   20   26     646
# 17   17   19     411
# 18   22   12     516
# 19   25   11     557
# 20   28   18     677
# 21   29   25     668
# 22   17   13     625
# 23   16   22     725
# 24   23   25     777
# 25   28   18     928
# 26   14   22     758
# 27   12   22     858
# 28   26   12     432
# 29   14   28     975
# 30   24   14     363
# 31   22   25     928
# 32   12   25     864
# 33   22   11     373
# 34   22   19     808
# 35   15   22     795
# 36   23   13     313
# 37   28   25     697
# 38   26   27     343
# 39   12   15     717
# 40   13   16     651
# 41   11   16     533
# ...

# %%
# random.randint(10, 30, size = 20)

# %%
sns.scatterplot(data, x = "abc", y = "xyz", size = "sizees", legend = False, color = "red")
# Out:
# <Axes: xlabel='abc', ylabel='xyz'>

# %%
dataset = pd.read_csv("StudentsPerformance_with_headers.csv")

# %%
dataset
# Out:
#      STUDENT ID  Student Age  Sex  Graduated high-school type  \
# 0      STUDENT1            2    2                           3
# 1      STUDENT2            2    2                           3
# 2      STUDENT3            2    2                           2
# 3      STUDENT4            1    1                           1
# 4      STUDENT5            2    2                           1
# ..          ...          ...  ...                         ...
# 140  STUDENT141            2    1                           2
# 141  STUDENT142            1    1                           2
# 142  STUDENT143            1    1                           1
# 143  STUDENT144            2    1                           2
# 144  STUDENT145            1    1                           1
#
#      Scholarship type  Additional work  Regular artistic or sports activity  \
# 0                   3                1                                    2
# ...
