# %%
# dataset genration

# %%
import numpy as np
import pandas as pd

# %%
x = 6 * np.random.rand(200, 1) - 3

# %%
x
# Out:
# array([[ 1.979764  ],
#        [ 2.13411934],
#        [ 0.18384416],
#        [ 2.72954069],
#        [ 1.17277715],
#        [ 2.68055736],
#        [ 2.24872997],
#        [-1.96110611],
#        [-2.73147462],
#        [-0.67569408],
#        [ 1.35117641],
#        [ 2.47859114],
#        [ 2.69243896],
#        [-0.30441609],
#        [ 0.30004165],
#        [ 2.3359414 ],
#        [-0.32920576],
#        [ 1.867332  ],
#        [ 0.47082135],
#        [-2.13607267],
#        [-0.66359495],
#        [-1.79529333],
#        [-0.62945923],
#        [ 0.93570424],
#        [ 1.47972182],
#        [ 0.99343229],
#        [ 0.35817739],
#        [-2.06195777],
#        [ 2.84074636],
#        [-0.01596459],
#        [ 1.29339967],
#        [-2.04074012],
#        [ 1.68910972],
#        [-0.42307609],
#        [-2.83786857],
#        [ 2.4229065 ],
#        [-0.03318874],
#        [-2.53601831],
#        [ 1.09032193],
#        [-0.76673275],
#        [ 1.15065784],
#        [-0.2853425 ],
#        [-2.65188968],
#        [ 2.71831165],
#        [ 1.90817279],
#        [-1.76412499],
#        [-0.61190374],
#        [ 0.34085218],
#        [-0.68949282],
#        [ 2.55883026],
#        [ 1.67141513],
#        [-2.20256972],
#        [-1.03596707],
#        [-2.31920972],
#        [ 2.61056459],
#        [ 2.54990074],
#        [ 2.11092952],
#        [ 1.48339543],
#        [ 0.49561099],
#        [ 1.19207717],
#        [ 2.05675392],
#        [ 1.71705173],
#        [ 1.05014348],
#        [-1.92874973],
#        [ 1.61625465],
#        [ 0.90036809],
#        [-2.39158124],
#        [ 0.38030522],
#        [-2.14684597],
#        [-0.16640136],
#        [ 1.55974043],
#        [ 2.86876924],
#        [-2.79937652],
#        [-2.31081872],
#        [-2.62825405],
#        [-1.09461724],
#        [-1.02731424],
#        [-0.37259453],
#        [-1.39625109],
#        [-0.62070849],
#        [ 0.23904436],
#        [-0.98230452],
#        [-1.52729875],
#        [-1.95555589],
#        [ 2.53551846],
#        [ 2.41459248],
#        [-2.15111195],
#        [-0.704535  ],
#        [ 0.76020165],
#        [-1.59578503],
#        [-1.33414847],
#        [ 0.06378082],
#        [-0.52907726],
#        [-1.27980214],
#        [-1.31493137],
#        [-0.21755126],
#        [ 2.6740445 ],
#        [-0.96121624],
#        [ 1.87140834],
#        [ 2.18994175],
#        [ 0.19748469],
#        [ 2.09954805],
#        [ 2.01019429],
#        [-2.47112736],
#        [ 2.96060435],
#        [ 2.91234833],
#        [-1.62723241],
#        [-1.82341852],
#        [-2.15532506],
#        [ 0.01409897],
#        [-0.2514351 ],
#        [-1.49762544],
#        [-2.56400029],
#        [ 0.50666482],
#        [ 2.22411153],
#        [-1.81625232],
#        [-1.81192096],
#        [ 0.07411334],
#        [-2.80962968],
#        [ 1.28930814],
#        [-1.83069397],
#        [ 0.80596988],
#        [-2.35894907],
#        [-1.44513819],
#        [ 1.1834223 ],
#        [-1.07099517],
#        [-1.99941299],
#        [ 0.45848814],
#        [-2.66517711],
#        [-0.82758386],
#        [-2.77361393],
#        [ 1.7073754 ],
#        [-2.9542046 ],
#        [-2.11684431],
#        [-1.20347937],
#        [-1.87399148],
#        [ 0.04318533],
#        [ 0.92572477],
#        [ 2.92505754],
#        [-2.62617796],
#        [-2.78901939],
#        [-0.37902871],
#        [-2.40440283],
#        [ 1.92319147],
#        [-1.66213388],
#        [ 0.39454004],
#        [-0.3823651 ],
#        [-0.98557983],
#        [-2.11327351],
#        [ 2.49490346],
#        [ 0.2258865 ],
#        [-1.1561248 ],
#        [ 0.624094  ],
#        [-1.25314605],
#        [-0.72841228],
#        [ 1.02942505],
#        [ 0.00556746],
#        [-1.42724066],
#        [-0.5793021 ],
#        [ 0.15055667],
#        [-0.99434475],
#        [-0.54248657],
#        [ 1.812816  ],
#        [ 2.98878594],
#        [-1.43109428],
#        [-0.80331445],
#        [ 2.84785995],
#        [ 0.50164055],
#        [ 2.58953274],
#        [-2.68691297],
#        [ 1.31692134],
#        [-1.09237505],
#        [-2.45126677],
#        [ 0.66940377],
#        [-1.34033084],
#        [-1.19553999],
#        [ 2.33971754],
#        [-2.82701695],
#        [-0.25691352],
#        [ 2.84447228],
#        [-0.29623955],
#        [-0.1718259 ],
#        [ 0.24086768],
#        [-2.60089712],
#        [-2.95888976],
#        [ 2.18734988],
#        [ 1.91084924],
#        [-1.15399673],
#        [-1.43898324],
#        [-2.67865363],
#        [ 0.76529838],
#        [-2.39512719],
#        [ 2.93959069],
#        [-0.91921756],
#        [-0.44568512],
#        [-2.08722165],
#        [ 2.84884669],
#        [-1.33019941],
#        [ 1.64274037],
#        [-2.90493029]])

# %%
y = 0.8 * x ** 2 + 0.9 * x + 2 + np.random.randn(200, 1)

# %%
y
# Out:
# array([[ 6.26511021],
#        [ 7.25331883],
#        [ 1.94397504],
#        [11.58279472],
#        [ 3.1083304 ],
#        [11.46124995],
#        [ 9.97285881],
#        [ 1.02026148],
#        [ 5.15361768],
#        [ 2.32721943],
#        [ 3.90279663],
#        [11.74110337],
#        [10.6803474 ],
#        [ 2.16938622],
#        [ 2.09590645],
#        [ 9.37940742],
#        [ 1.39084684],
#        [ 7.20936432],
#        [ 2.8909813 ],
#        [ 2.21308391],
#        [ 2.01549791],
#        [ 2.80716278],
#        [ 1.68040072],
#        [ 2.60910258],
#        [ 4.7250392 ],
#        [ 4.33705078],
#        [ 2.57919848],
#        [ 2.90390616],
#        [11.99426048],
#        [ 2.18132287],
#        [ 3.27611215],
#        [ 1.56218687],
#        [ 6.06353244],
#        [ 1.10065458],
#        [ 4.99459013],
#        [ 8.07265021],
#        [ 0.99463634],
#        [ 8.97029624],
#        [ 4.96181959],
#        [ 2.57461558],
#        [ 2.91685692],
#        [ 2.01463011],
#        [ 4.04570858],
#        [ 8.65157231],
#        [ 6.0769027 ],
#        [ 3.74625508],
#        [ 2.37506269],
#        [ 2.70250781],
#        [ 1.0853431 ],
#        [11.43017647],
#        [ 5.74276166],
#        [ 5.63343479],
#        [ 3.11707986],
#        [ 4.90141864],
#        [10.42658902],
#        [10.66140504],
#        [ 6.66461869],
#        [ 4.37131983],
#        [ 3.04448772],
#        [ 5.27510299],
#        [ 6.48762517],
#        [ 6.83873229],
#        [ 3.7631761 ],
#        [ 2.59212914],
#        [ 5.27960582],
#        [ 2.82716143],
#        [ 4.92903698],
#        [ 1.65834598],
#        [ 3.10652469],
#        [ 2.60537736],
#        [ 5.1381531 ],
#        [10.58144338],
#        [ 5.95253865],
#        [ 4.59861089],
#        [ 6.57905841],
#        [ 1.95256724],
#        [ 1.67864412],
#        [ 3.01568492],
#        [ 2.12347362],
#        [ 2.13364017],
#        [ 1.28003677],
#        [-0.20990286],
#        [ 2.90990726],
#        [ 2.51074732],
#        [ 8.80699496],
#        [ 9.40022896],
#        [ 3.02198681],
#        [ 0.09249532],
#        [ 1.75363781],
#        [ 1.14903451],
#        [ 2.11840243],
#        [-0.52345741],
#        [ 0.74833646],
#        [ 3.31119928],
#        [ 1.18333661],
#        [ 2.87553624],
#        [ 9.52726318],
#        [ 0.79808619],
#        [ 7.930497  ],
#        [ 7.76802443],
#        [ 0.55457594],
#        [ 7.7649532 ],
#        [ 7.64053822],
#        [ 4.75982787],
#        [12.06963115],
#        [11.53871172],
#        [ 3.67495351],
#        [ 3.18702881],
#        [ 2.27441547],
#        [ 2.94700758],
#        [ 1.2123779 ],
#        [ 2.33373597],
#        [ 5.77423856],
#        [ 2.85941268],
#        [ 7.47439637],
#        [ 2.12064614],
#        [ 4.14055791],
#        [ 2.87661283],
#        [ 5.89151054],
#        [ 4.36400885],
#        [ 3.22957746],
#        [ 2.03249906],
#        [ 3.81932431],
#        [ 1.61888005],
#        [ 4.87645581],
#        [ 1.36967524],
#        [ 3.02689599],
#        [ 4.84690348],
#        [ 5.016114  ],
#        [ 3.14589373],
#        [ 4.58094204],
#        [ 5.46793752],
#        [ 4.03677416],
#        [ 4.66823906],
#        [ 1.59660878],
#        [ 3.97035823],
#        [ 1.25183505],
#        [ 3.83410392],
#        [11.00993818],
#        [ 5.41991865],
#        [ 5.18227607],
#        [ 1.73781076],
#        [ 5.44746547],
#        [ 7.71826306],
#        [ 2.85354026],
#        [ 2.48536262],
#        [ 1.55279402],
#        [-0.13158887],
#        [ 3.76890924],
#        [ 9.63022832],
#        [ 1.66892981],
#        [ 1.10830455],
#        [ 2.55849096],
#        [ 2.37723914],
#        [ 3.4999089 ],
#        [ 3.2050989 ],
#        [ 3.17344082],
#        [ 1.96550608],
#        [ 1.72771221],
#        [ 3.69024236],
#        [ 0.76076825],
#        [ 4.06039305],
#        [ 6.95369104],
#        [10.0855645 ],
#        [ 2.14958741],
#        [ 1.471375  ],
#        [11.16628254],
#        [ 2.55834606],
#        [ 7.95082693],
#        [ 5.01306433],
#        [ 7.06941239],
#        [ 3.57188924],
#        [ 5.64461529],
#        [ 3.59046471],
#        [ 2.3925315 ],
#        [ 4.42081318],
#        [ 8.7144019 ],
#        [ 7.72181655],
#        [ 0.56793541],
#        [10.67454343],
#        [ 0.69244257],
#        [ 3.30019884],
#        [ 2.36503108],
#        [ 6.10601804],
#        [ 6.69917713],
#        [ 8.01536039],
#        [ 5.62730958],
#        [ 2.62106366],
#        [ 2.5092861 ],
#        [ 4.92074742],
#        [ 2.99050084],
#        [ 3.98855615],
#        [11.8988121 ],
#        [ 0.79066098],
#        [ 2.6490521 ],
#        [ 4.66747666],
#        [10.31979476],
#        [ 2.83958651],
#        [ 6.53309999],
#        [ 6.82076624]])

# %%
new_x = np.reshape(x, -1)
# new_x
new_y = np.reshape(y, -1)

# %%
data = pd.DataFrame({
    "feature" : new_x,
    "ouput" : new_y
})

# %%
data
# Out:
#       feature      ouput
# 0    1.979764   6.265110
# 1    2.134119   7.253319
# 2    0.183844   1.943975
# 3    2.729541  11.582795
# 4    1.172777   3.108330
# ..        ...        ...
# 195 -2.087222   4.667477
# 196  2.848847  10.319795
# 197 -1.330199   2.839587
# 198  1.642740   6.533100
# 199 -2.904930   6.820766
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["feature"], data["ouput"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_only = data.iloc[0:1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
x_test.shape
# Out:
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred, y_test)
# Out:
# -1.3011312583897965

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.plot(x_test, y_pred, label = "Predicted Line")
plt.legend()

# %% [markdown]
# ## Apply Polynomal Linear Regression

# %%
# data

# %%
# x --> input column

# degree ==> 2

# x0, x1, x2

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 3)

# %%
# x_train

x_train_new = poly.fit_transform(x_train)
# x_train_new
x_test_new = poly.fit_transform(x_test)
x_train_new
# Out:
# array([[ 1.00000000e+00,  1.15065784e+00,  1.32401347e+00,
#          1.52348649e+00],
#        [ 1.00000000e+00, -1.71825905e-01,  2.95241416e-02,
#         -5.07301235e-03],
#        [ 1.00000000e+00,  2.84785995e+00,  8.11030630e+00,
#          2.30970165e+01],
#        [ 1.00000000e+00, -1.81192096e+00,  3.28305757e+00,
#         -5.94864082e+00],
#        [ 1.00000000e+00,  1.48339543e+00,  2.20046201e+00,
#          3.26415530e+00],
#        [ 1.00000000e+00, -2.13607267e+00,  4.56280645e+00,
#         -9.74648614e+00],
#        [ 1.00000000e+00, -2.31081872e+00,  5.33988318e+00,
#         -1.23395020e+01],
#        [ 1.00000000e+00,  2.84884669e+00,  8.11592746e+00,
#          2.31210331e+01],
#        [ 1.00000000e+00, -1.49762544e+00,  2.24288197e+00,
#         -3.35899710e+00],
#        [ 1.00000000e+00, -1.82341852e+00,  3.32485510e+00,
#         -6.06260236e+00],
#        [ 1.00000000e+00, -1.87399148e+00,  3.51184407e+00,
#         -6.58116586e+00],
#        [ 1.00000000e+00,  1.61625465e+00,  2.61227910e+00,
#          4.22210824e+00],
#        [ 1.00000000e+00, -9.61216240e-01,  9.23936661e-01,
#         -8.88102924e-01],
#        [ 1.00000000e+00,  9.25724773e-01,  8.56966355e-01,
#          7.93314984e-01],
#        [ 1.00000000e+00, -1.43109428e+00,  2.04803083e+00,
#         -2.93092520e+00],
#        [ 1.00000000e+00,  2.84074636e+00,  8.06983988e+00,
#          2.29243682e+01],
#        [ 1.00000000e+00,  2.69243896e+00,  7.24922753e+00,
#          1.95181026e+01],
#        [ 1.00000000e+00, -9.19217556e-01,  8.44960915e-01,
#         -7.76702907e-01],
#        [ 1.00000000e+00, -2.85342496e-01,  8.14203399e-02,
#         -2.32326830e-02],
#        [ 1.00000000e+00, -6.89492818e-01,  4.75400346e-01,
#         -3.27785124e-01],
#        [ 1.00000000e+00,  2.72954069e+00,  7.45039237e+00,
#          2.03361491e+01],
#        [ 1.00000000e+00,  1.05014348e+00,  1.10280132e+00,
#          1.15809962e+00],
#        [ 1.00000000e+00,  4.58488136e-01,  2.10211371e-01,
#          9.63794194e-02],
#        [ 1.00000000e+00,  2.49490346e+00,  6.22454330e+00,
#          1.55296346e+01],
#        [ 1.00000000e+00,  3.58177390e-01,  1.28291043e-01,
#          4.59509509e-02],
#        [ 1.00000000e+00, -2.62617796e+00,  6.89681068e+00,
#         -1.81122522e+01],
#        [ 1.00000000e+00, -7.04534999e-01,  4.96369565e-01,
#         -3.49709731e-01],
#        [ 1.00000000e+00,  1.55974043e+00,  2.43279020e+00,
#          3.79452123e+00],
#        [ 1.00000000e+00, -1.15612480e+00,  1.33662456e+00,
#         -1.54530481e+00],
#        [ 1.00000000e+00,  5.01640547e-01,  2.51643238e-01,
#          1.26234452e-01],
#        [ 1.00000000e+00, -1.39625109e+00,  1.94951710e+00,
#         -2.72201538e+00],
#        [ 1.00000000e+00, -1.66401356e-01,  2.76894113e-02,
#         -4.60755558e-03],
#        [ 1.00000000e+00, -2.14684597e+00,  4.60894760e+00,
#         -9.89470056e+00]])

# %%
# x_train

# %%
# x_train_new_data = x_test_new.iloc[:, 0:2]

# %%
df = pd.DataFrame({
    "feature1" : x_train_new[:, 0],
    "feature2" : x_train_new[:, 1],
    "feature3" : x_train_new[:, 2],
    "output" : y_train.reshape(-1)
})


df
# Out:
#      feature1  feature2  feature3     output
# 0         1.0  1.150658  1.324013   2.916857
# 1         1.0 -0.171826  0.029524   3.300199
# 2         1.0  2.847860  8.110306  11.166283
# 3         1.0 -1.811921  3.283058   4.140558
# 4         1.0  1.483395  2.200462   4.371320
# ..        ...       ...       ...        ...
# 155       1.0 -1.156125  1.336625   1.108305
# 156       1.0  0.501641  0.251643   2.558346
# 157       1.0 -1.396251  1.949517   2.123474
# 158       1.0 -0.166401  0.027689   2.605377
# 159       1.0 -2.146846  4.608948   3.106525
#
# [160 rows x 4 columns]

# %%
x_data = df.iloc[: , 0:3]
x_data
# Out:
#      feature1  feature2  feature3
# 0         1.0  1.150658  1.324013
# 1         1.0 -0.171826  0.029524
# 2         1.0  2.847860  8.110306
# 3         1.0 -1.811921  3.283058
# 4         1.0  1.483395  2.200462
# ..        ...       ...       ...
# 155       1.0 -1.156125  1.336625
# 156       1.0  0.501641  0.251643
# 157       1.0 -1.396251  1.949517
# 158       1.0 -0.166401  0.027689
# 159       1.0 -2.146846  4.608948
#
# [160 rows x 3 columns]

# %%
xyz = LinearRegression()

# %%
xyz.fit(x_train_new, y_train)
# Out:
# LinearRegression()

# %%
df_test = pd.DataFrame({
    "feature1" : x_test_new[:, 0],
    "feature2" : x_test_new[:, 1],
    "feature3" : x_test_new[:, 2],
    "output" : y_test.reshape(-1)
})


df_test
# Out:
#     feature1  feature2  feature3     output
# 0        1.0 -0.304416  0.092669   2.169386
# 1        1.0  0.239044  0.057142   1.280037
# 2        1.0 -2.773614  7.692934   4.580942
# 3        1.0 -0.296240  0.087758   0.692443
# 4        1.0 -1.816252  3.298772   2.120646
# 5        1.0 -1.795293  3.223078   2.807163
# 6        1.0  2.868769  8.229837  10.581443
# 7        1.0 -2.958890  8.755029   6.699177
# 8        1.0  1.479722  2.189577   4.725039
# 9        1.0 -1.153997  1.331708   2.621064
# 10       1.0 -2.600897  6.764666   6.106018
# 11       1.0 -2.904930  8.438620   6.820766
# 12       1.0 -1.445138  2.088424   1.618880
# 13       1.0  0.765298  0.585682   2.990501
# 14       1.0 -2.651890  7.032519   4.045709
# 15       1.0 -0.827584  0.684895   3.145894
# 16       1.0 -2.837869  8.053498   4.994590
# 17       1.0 -0.256914  0.066005   0.567935
# 18       1.0 -1.595785  2.546530   1.149035
# 19       1.0 -1.334148  1.779952   2.118402
# 20       1.0  2.674045  7.150514   9.527263
# 21       1.0 -1.070995  1.147031   1.369675
# 22       1.0 -2.686913  7.219501   5.013064
# 23       1.0 -2.678654  7.175185   4.920747
# 24       1.0 -1.438983  2.070673   2.509286
# 25       1.0 -2.665177  7.103169   5.016114
# 26       1.0 -0.620708  0.385279   2.133640
# 27       1.0 -1.764125  3.112137   3.746255
# 28       1.0  1.812816  3.286302   6.953691
# 29       1.0  1.192077  1.421048   5.275103
# 30       1.0 -0.251435  0.063220   1.212378
# 31       1.0  0.240868  0.058017   2.365031
# 32       1.0 -0.372595  0.138827   3.015685
# 33       1.0  0.394540  0.155662   2.485363
# 34       1.0  2.558830  6.547612  11.430176
# 35       1.0 -2.451267  6.008709   5.644615
# 36       1.0 -1.092375  1.193283   3.571889
# 37       1.0  1.351176  1.825678   3.902797
# 38       1.0 -0.985580  0.971368  -0.131589
# 39       1.0 -2.040740  4.164620   1.562187

# %%
x_data_test = df_test.iloc[: , 0:3]
x_data_test
# Out:
#     feature1  feature2  feature3
# 0        1.0 -0.304416  0.092669
# 1        1.0  0.239044  0.057142
# 2        1.0 -2.773614  7.692934
# 3        1.0 -0.296240  0.087758
# 4        1.0 -1.816252  3.298772
# 5        1.0 -1.795293  3.223078
# 6        1.0  2.868769  8.229837
# 7        1.0 -2.958890  8.755029
# 8        1.0  1.479722  2.189577
# 9        1.0 -1.153997  1.331708
# 10       1.0 -2.600897  6.764666
# 11       1.0 -2.904930  8.438620
# 12       1.0 -1.445138  2.088424
# 13       1.0  0.765298  0.585682
# 14       1.0 -2.651890  7.032519
# 15       1.0 -0.827584  0.684895
# 16       1.0 -2.837869  8.053498
# 17       1.0 -0.256914  0.066005
# 18       1.0 -1.595785  2.546530
# 19       1.0 -1.334148  1.779952
# 20       1.0  2.674045  7.150514
# 21       1.0 -1.070995  1.147031
# 22       1.0 -2.686913  7.219501
# 23       1.0 -2.678654  7.175185
# 24       1.0 -1.438983  2.070673
# 25       1.0 -2.665177  7.103169
# 26       1.0 -0.620708  0.385279
# 27       1.0 -1.764125  3.112137
# 28       1.0  1.812816  3.286302
# 29       1.0  1.192077  1.421048
# 30       1.0 -0.251435  0.063220
# 31       1.0  0.240868  0.058017
# 32       1.0 -0.372595  0.138827
# 33       1.0  0.394540  0.155662
# 34       1.0  2.558830  6.547612
# 35       1.0 -2.451267  6.008709
# 36       1.0 -1.092375  1.193283
# 37       1.0  1.351176  1.825678
# 38       1.0 -0.985580  0.971368
# 39       1.0 -2.040740  4.164620

# %%
y_pred_new = xyz.predict(x_data_test)

# %%
# y_pred_new

# %%
r2_score(y_pred, y_test)
# Out:
# -1.3011312583897965

# %%
r2_score(y_pred_new, y_test)
# Out:
# 0.8380133435036166

# %%
xyz.coef_
# Out:
# array([[0.        , 0.88725436, 0.82092083]])

# %%
xyz.intercept_
# Out:
# array([2.00536759])

# %%
x_new = np.linspace(-3, 3, 200).reshape(200, 1)
x_new_ploy = poly.fit_transform(x_new)
x_new = xyz.predict(x_new_ploy)

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.plot(x_new, y_new, label = "Predicted Line", linewidth = 3, color = "blue")
plt.legend()

# %%
from sklearn.preprocessing import StandardScaler

# %%
def ploynomiaol_degree_checker(degree):
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

    poly = PolynomialFeatures(degree = degree)
    x_train_new = poly.fit_transform(x_train)
    x_test_new = poly.fit_transform(x_test)
    # std_scaler = StandardScaler()
    lin_reg = LinearRegression()
    
    xyz.fit(x_train_new, y_train)
    
    df_test = pd.DataFrame({
        "feature1" : x_test_new[:, 0],
        "feature2" : x_test_new[:, 1],
        "feature3" : x_test_new[:, 2],
        "output" : y_test.reshape(-1)
    })

    x_data_test = df_test.iloc[: , 0:3]
    y_pred_new = xyz.predict(x_data_test)
    r2_score(y_pred_new, y_test)

    x_new = np.linspace(-3, 3, 200).reshape(200, 1)
    x_new_ploy = poly.fit_transform(x_new)
    x_new = xyz.predict(x_new_ploy)

    plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
    plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
    plt.plot(x_new, y_new, label = "Predicted Line", linewidth = 3, color = "blue")
    plt.legend()

# %%
ploynomiaol_degree_checker(2)
# Out:
# C:\Users\17nru\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.pipeline import Pipeline

# %%
def polynomial_regression(degree):
    X_new=np.linspace(-3, 3, 100).reshape(100, 1)
    X_new_poly = poly.transform(X_new)

    polybig_features = PolynomialFeatures(degree=degree, include_bias=False)
    std_scaler = StandardScaler()
    lin_reg = LinearRegression()
    polynomial_regression = Pipeline([
            ("poly_features", polybig_features),
            ("std_scaler", std_scaler),
            ("lin_reg", lin_reg),
        ])
    polynomial_regression.fit(x, y)
    y_newbig = polynomial_regression.predict(X_new)
    plt.plot(X_new, y_newbig,'r', label="Degree " + str(degree), linewidth=2)

    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-3, 3, 0, 10])
    plt.show()

# %%
polynomial_regression(3)
