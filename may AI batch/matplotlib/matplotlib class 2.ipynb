# %%
# Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([12, 34, 45, 56, 76, 80])
y = np.array([34, 5, 34, 23, 45, 67])

# %%
plt.plot(x, y, marker = "*")

# %%
plt.plot(x, y, marker = "*", ms = 12, mec = "green", mfc = "yellow")

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow")

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow", linewidth = 3, color = "red", linestyle = "dashdot")

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow", linewidth = 3, color = "red", linestyle = "dashdot")
plt.xlabel("this is x-axis")
plt.ylabel("this is y-axis")
plt.title("this is a atitle")
# Out:
# Text(0.5, 1.0, 'this is a atitle')

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow", linewidth = 3, color = "red", linestyle = "dashdot")
plt.xlabel("this is x-axis")
plt.ylabel("this is y-axis")
plt.title("this is a atitle")
plt.grid()

# %%
x = np.array([12, 34, 45, 56, 76, 80])
y = np.array([34, 5, 34, 23, 45, 67])

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow", linewidth = 3, color = "red", linestyle = "dashdot")
plt.xlabel("this is x-axis")
plt.ylabel("this is y-axis")
plt.title("this is a atitle")
plt.grid()


plt.annotate("helo", x[2], y[4])

# for i in range(len(x)):
#     plt.annotate(x = x[i], y = y[i], )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       4 plt.title("this is a atitle")
#       5 plt.grid()
# ----> 8 plt.annotate("helo", x[2], y[4])
#      10 # for i in range(len(x)):
#      11 #     plt.annotate(x = x[i], y = y[i], )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2647, in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2627 @_copy_docstring_and_deprecators(Axes.annotate)
#    2628 def annotate(
#    2629     text: str,
#    (...)
#    2645     **kwargs,
#    2646 ) -> Annotation:
# -> 2647     return gca().annotate(
#    2648         text,
#    2649         xy,
#    2650         xytext=xytext,
#    2651         xycoords=xycoords,
#    2652         textcoords=textcoords,
#    2653         arrowprops=arrowprops,
# ...

# %%
# help(plt.annotate)

# %%
x = np.array([12, 34, 45, 56, 76, 80])
y = np.array([34, 5, 34, 23, 45, 67])

# %%
plt.plot(x, y, marker = "*", ms = 15, mec = "green", mfc = "yellow", linewidth = 3, color = "red", linestyle = "dashdot")
plt.xlabel("this is x-axis")
plt.ylabel("this is y-axis")
plt.title("this is a atitle")
plt.grid()

for i in range(len(x)):
                        # (12, 34)
    plt.annotate(xy = (x[i], y[i]), text = f"({x[i]}, {y[i]})", color = "red")

# %% [markdown]
# ## Scatter Plot

# %%
# numpy:

# arange() ------ range()

# %%
# for i in range(1, 20):
#     print(i)

# %%
x = np.array([12, 23, 34, 45, 2, 4, 56, 34, 23, 34, 23, 23])

# %%
y = np.array([34, 45, 3, 23, 34, 23, 34, 23, 34, 23, 23, 34, 45])

# %%
plt.scatter(x, y)

# %%
xyz = np.array([12, 34, 45, 67, 34])
abc = np.array([23, 45, 56, 78, 34])

# %%
p = np.array([3, 45, 67, 34, 23, 23, 45, 4])
q = np.array([34, 56, 78, 89, 34, 56, 34, 3])

# %%
plt.plot(xyz, abc)
plt.plot(p, q)

# %%
age = np.array([12, 34, 45, 67, 78, 89])
income = np.array([23, 45, 67, 75, 34, 23])

investmenet = np.array([23, 45, 56, 78, 56, 78, 89, 56])
achive = np.array([23, 45, 67, 45, 56, 34, 45, 34])

# %%
plt.plot(age, income, label = "User age & income", marker = "*", ms = 15)
plt.plot(investmenet, achive, label = "achivements", marker = ".", ms = 15)
plt.legend()

# %%
# Scater:::::::::::

# %%
age = np.array([12, 34, 45, 67, 78, 89])
income = np.array([23, 45, 67, 75, 34, 23])

# %%
x = ["red", "yellow", "black", "orange", "green", "blue"]

# %%
plt.scatter(age, income, color = x)

# %%
investmenet = np.array([23, 45, 56, 78, 56, 78, 89, 56])
achive = np.array([23, 45, 67, 45, 56, 34, 45, 34])

# %%
age = np.array([12, 34, 56, 34, 56, 67, 4, 45, 67])

# %%
investmet = np.array([12, 45, 45, 67, 45, 67, 45, 67, 54])

# %%
income = [500, 800, 900, 500, 340, 400, 100, 200, 700]

# %%
plt.scatter(age, investmet, s=income, label = "Income", color = "red")
plt.scatter(investmenet, achive, label = "info")
plt.grid(linestyle = "dotted", color = "green")
plt.xlabel("User age")
plt.ylabel("Investment")
plt.title("user detail", color = "red")
plt.legend()
