# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("place.csv")

# %%
plt.scatter(data["cgpa"], data["package"])

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.iloc[:, 0:1]
y = data.iloc[:, -1]

# %%
x_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
obj.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\programography\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(data["cgpa"], data["package"])
plt.plot(x_train, obj.predict(x_train))

# %%
# y = mx + b
m = obj.coef_
b = obj.intercept_

# %%
from sklearn.metrics import r2_score
y_pred = obj.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.780730147510384
