# %%
import pandas as pd

# %%
data = pd.read_csv("sharma-kohli.csv")

# %%
data
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
z = data["index"]
y = data["RG Sharma"]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(z, y)
for i in range(len(z)):
    plt.annotate((z[i], y[i]), (z[i], y[i]))

# %%
import pandas as pd

# %%
data = pd.read_csv("sharma-kohli.csv")

# %%
data
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
import matplotlib.pyplot as plt

# %%
data
x = data["index"]
y = data["RG Sharma"]
z = data["V Kohli"]

# %%
z
# Out:
# 0    165
# 1    246
# 2    307
# 3    557
# 4    364
# 5    639
# 6    359
# 7    505
# 8    973
# 9    308
# Name: V Kohli, dtype: int64

# %%
plt.plot(x, y, label = "RAhul Sharm", marker = "o", linestyle="dashed")
plt.plot(x, z, label="virat", marker="<", linestyle="dotted")
plt.xlabel("Years")
plt.ylabel("Scores")
plt.title("Comparision")
plt.grid()
plt.legend()
